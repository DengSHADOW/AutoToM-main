# %%
import os
import os
os.environ["OPENAI_API_KEY"] = "your-api-key-here"
if os.path.basename(os.getcwd()) != "model":
    os.chdir("model")

print("Current folder:", os.getcwd())
# Out:
# Current folder: c:\Users\shado\Desktop\26spring\MSI\Project\AutoToM-main\model

# %%
# Example usage for customized questions
story = """1 Ella entered the master_bedroom.
2 Ava entered the master_bedroom.
3 The onion is in the envelope.
4 The envelope is in the master_bedroom.
5 Ella exited the master_bedroom.
6 Ava moved the onion to the box.
7 The box is in the master_bedroom.
8 Ava exited the master_bedroom.
9 Ella entered the hallway."""
question = "Where will Ella look for the onion?"
choices = ["envelope", "box"] # Correct answer is envelope.
dataset_name = "customize"
episode_name = "customize_0"
verbose = False

# %%
from ProbSolver import ProblemSolver, argmax, argmin
solver = ProblemSolver(
        story=story,
        question=question,
        choices=choices,
        K=1,
        assigned_model=[],
        model_name="automated",
        episode_name=episode_name,
        llm="gpt-4o",
        verbose=verbose,
        dataset_name=dataset_name,
        hypo_method="guided",
        nested=False,
        video_id=None,
        answerfunc=argmax,
        back_inference=True,
        reduce_hypotheses=True,
        precomputed_states=None,
        precomputed_actions=None,
        prev_hyp=None,
        no_model_adjustment=False,
        recursion_depth=None
    )

final_probs, model_record = solver.solve()
# Out:
# Extracted actions: ['Ella entered the master bedroom.', 'Ella exited the master bedroom.', 'Ella entered the hallway.']
# Initial Model proposed:  ['State', 'Observation', 'Belief']
# Starting from timestep 2
# Hypotheses proposed for Observation
# ['Ella sees that the onion is in the envelope.']
# Hypotheses proposed for Observation
# ['Ella sees that the onion is in the box.']
# Determine if the statement is likely, respond with only either A or B.
# State: Ella is not in the master bedroom. The onion is in the box in the master bedroom. Ava is not in the master bedroom. The box is in the master bedroom.
# Here is a statement of Ella's current observation. Only evaluate current observation of Ella based on the state. Do not imagine anything else. Think about Ella's location. Ella is quite likely to observe all objects and events in Ella's location, and is unlikely to observe states in another location. If Ella does not appear in the state, Ella can't observe anything. Note that the statement has to be precise in wording to be likely. For example, treasure chest and container are different in wording and they're different objects.
# Determine if the following statement is likely: Ella sees that the onion is in the envelope.
# A) Likely.
# B) Unlikely.
#  8.315279260963632e-07
# Determine if the statement is likely, respond with only either A or B.
# State: Ella is not in the master bedroom. The onion is in the box in the master bedroom. Ava is not in the master bedroom. The box is in the master bedroom.
# Here is a statement of Ella's current observation. Only evaluate current observation of Ella based on the state. Do not imagine anything else. Think about Ella's location. Ella is quite likely to observe all objects and events in Ella's location, and is unlikely to observe states in another location. If Ella does not appear in the state, Ella can't observe anything. Note that the statement has to be precise in wording to be likely. For example, treasure chest and container are different in wording and they're different objects.
# Determine if the following statement is likely: Ella sees that the onion is in the box.
# A) Likely.
# B) Unlikely.
#  1.994729895832688e-06
# Determine if the statement is likely, respond with only either A or B.
# State: Ella is not in the master bedroom. The onion is in the box in the master bedroom. Ava is not in the master bedroom. The box is in the master bedroom.
# Here is a statement of Ella's current observation. Only evaluate current observation of Ella based on the state. Do not imagine anything else. Think about Ella's location. Ella is quite likely to observe all objects and events in Ella's location, and is unlikely to observe states in another location. If Ella does not appear in the state, Ella can't observe anything. Note that the statement has to be precise in wording to be likely. For example, treasure chest and container are different in wording and they're different objects.
# Determine if the following statement is likely: Ella does not see the onion.
# A) Likely.
# B) Unlikely.
#  0.9997684772251865
# Node results saved to ../results/node_results/automated_customize_0_back1_reduce1.csv
# After time 2: Ella's Belief Probs calculated as ['Ella will look for the onion in the envelope.', 'Ella will look for the onion in the box.'], [0.5, 0.5]
# Initial Terminate:  False
# Initial Utility:  -0.6931471805599453
# Hypotheses proposed for Goal
# ['Ella wants to find the onion.']
# Hypotheses proposed for Goal
# ['Ella wants to find the onion.']
# Determine if the statement is likely, respond with only either A or B.
# Ella's Goal: Ella wants to find the onion.
# Ella's Belief: Ella will look for the onion in the envelope.
# Here is a statement of Ella's action. The belief stands for Ella's current belief which is true. Ella is likely to act according to goal and belief concerning certain objects (the wording for objects must be same. You should ignore the correlation of different objects. e.g., plate and apple are two different objects.) Notice that Ella's belief does not represent the goal.
# When belief and goal are irrelevant, and action is directly driven by goal, it's likely. When belief and goal are relevant (about exactly the same object) and they contradict (or irrelevant) with action, it's unlikely.
# Determine if the following statement is likely: Ella entered the hallway.
# A) Likely.
# B) Unlikely.
#  0.26893601919720794
# Determine if the statement is likely, respond with only either A or B.
# Ella's Goal: Ella wants to find the onion.
# Ella's Belief: Ella will look for the onion in the box.
# Here is a statement of Ella's action. The belief stands for Ella's current belief which is true. Ella is likely to act according to goal and belief concerning certain objects (the wording for objects must be same. You should ignore the correlation of different objects. e.g., plate and apple are two different objects.) Notice that Ella's belief does not represent the goal.
# When belief and goal are irrelevant, and action is directly driven by goal, it's likely. When belief and goal are relevant (about exactly the same object) and they contradict (or irrelevant) with action, it's unlikely.
# Determine if the following statement is likely: Ella entered the hallway.
# A) Likely.
# B) Unlikely.
#  0.10669010899354982
# Node results saved to ../results/node_results/automated_customize_0_back1_reduce1.csv
# After time 2: Ella's Belief Probs calculated as ['Ella will look for the onion in the envelope.', 'Ella will look for the onion in the box.'], [0.7159672850569959, 0.2840327149430041]
# Probs results saved to ../results/probs/automated_customize_0.csv
# Model test:  ['State', 'Observation', 'Belief', 'Action', 'Goal']
# Model test results:  [0.7159672850569959, 0.2840327149430041]
# Initial Utility:  -0.6931471805599453
# Utility Experiments:  {'Action': np.float64(-0.5967218448706821)}
# Hypotheses proposed for Goal
# ['Ella wants to find the onion.']
# Hypotheses proposed for Goal
# ['Ella wants to find the onion.']
# Node results saved to ../results/node_results/automated_customize_0_back1_reduce1.csv
# After time 2: Ella's Belief Probs calculated as ['Ella will look for the onion in the envelope.', 'Ella will look for the onion in the box.'], [0.7159672850569959, 0.2840327149430041]
# Probs results saved to ../results/probs/automated_customize_0.csv
# {'Initial model propose': ['State', 'Observation', 'Belief'], 'Assigned models': {2: ['State', 'Observation', 'Belief', 'Action', 'Goal']}}

# %%
print(choices, final_probs)
# Out:
# ['envelope', 'box'] [0.7159672850569959, 0.2840327149430041]
