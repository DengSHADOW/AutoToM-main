# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY", "")

# %%
# Example usage for customized questions
story = """1 Ella entered the master_bedroom.
2 Ava entered the master_bedroom.
3 The onion is in the envelope.
4 The envelope is in the master_bedroom.
5 Ella exited the master_bedroom.
6 Ava moved the onion to the box.
7 The box is in the master_bedroom.
8 Ava exited the master_bedroom.
9 Ella entered the hallway."""
question = "Where will Ella look for the onion?"
choices = ["envelope", "box"] # Correct answer is envelope.
dataset_name = "customize"
episode_name = "customize_0"
verbose = False

# %%
from ProbSolver import ProblemSolver, argmax, argmin
solver = ProblemSolver(
        story=story,
        question=question,
        choices=choices,
        K=1,
        assigned_model=[],
        model_name="automated",
        episode_name=episode_name,
        llm="gpt-4o",
        verbose=verbose,
        dataset_name=dataset_name,
        hypo_method="guided",
        nested=False,
        video_id=None,
        answerfunc=argmax,
        back_inference=True,
        reduce_hypotheses=True,
        precomputed_states=None,
        precomputed_actions=None,
        prev_hyp=None,
        no_model_adjustment=False,
        recursion_depth=None
    )

final_probs, model_record = solver.solve()
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[3], line 26
#       1 from ProbSolver import ProblemSolver, argmax, argmin
#       2 solver = ProblemSolver(
#       3         story=story,
#       4         question=question,
#    (...)
#      23         recursion_depth=None
#      24     )
# ---> 26 final_probs, model_record = solver.solve()
#
# File c:\Users\shado\Desktop\26spring\MSI\Project\AutoToM-main\model\ProbSolver.py:606, in ProblemSolver.solve(self)
#     604 ### Parsing ###
#     605 if self.model_name == "automated":
# --> 606     if determine_realistic_questions(self.question) is True:
#     607         self.realistic = True
#     608         self.nested = False
#
# File c:\Users\shado\Desktop\26spring\MSI\Project\AutoToM-main\model\model_adjustment.py:323, in determine_realistic_questions(question)
#     308 def determine_realistic_questions(question):
#     309     prompt = f"Determine whether the question is about realistic physical states. \
#     310         It is about physical world states if it involves no agent. \n\
#     311         Please respond with 'Yes' or 'No'. \n\
#    (...)
#     321         Question: {question} \
#     322         Realistic: "
# --> 323     response = gpt_call(prompt)
#     324     if response == "Yes":
#     325         return True
#
# File c:\Users\shado\Desktop\26spring\MSI\Project\AutoToM-main\model\model_adjustment.py:255, in gpt_call(prompt)
#     254 def gpt_call(prompt):
# --> 255     response = openai.chat.completions.create(
#     256         model="gpt-4o",
#     257         messages=[
#     258             {"role": "system", "content": "You are a helpful assistant."},
#     259             {"role": "user", "content": prompt},
#     260         ],
#     261         temperature=0,
#     262     )
#     264     return response.choices[0].message.content
#
# File c:\Users\shado\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:20, in LazyProxy.__getattr__(self, attr)
#      19 def __getattr__(self, attr: str) -> object:
# ---> 20     proxied = self.__get_proxied__()
#      21     if isinstance(proxied, LazyProxy):
#      22         return proxied  # pyright: ignore
#
# File c:\Users\shado\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:58, in LazyProxy.__get_proxied__(self)
#      57 def __get_proxied__(self) -> T:
# ---> 58     return self.__load__()
#
# File c:\Users\shado\anaconda3\Lib\site-packages\openai\_module_client.py:38, in ChatProxy.__load__(self)
#      36 @override
#      37 def __load__(self) -> Chat:
# ---> 38     return _load_client().chat
#
# File c:\Users\shado\anaconda3\Lib\site-packages\openai\__init__.py:351, in _load_client()
#     335         _client = _AzureModuleClient(  # type: ignore
#     336             api_version=api_version,
#     337             azure_endpoint=azure_endpoint,
#    (...)
#     347             http_client=http_client,
#     348         )
#     349         return _client
# --> 351     _client = _ModuleClient(
#     352         api_key=api_key,
#     353         organization=organization,
#     354         project=project,
#     355         webhook_secret=webhook_secret,
#     356         base_url=base_url,
#     357         timeout=timeout,
#     358         max_retries=max_retries,
#     359         default_headers=default_headers,
#     360         default_query=default_query,
#     361         http_client=http_client,
#     362     )
#     363     return _client
#     365 return _client
#
# File c:\Users\shado\anaconda3\Lib\site-packages\openai\_client.py:139, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     137     api_key = os.environ.get("OPENAI_API_KEY")
#     138 if api_key is None:
# --> 139     raise OpenAIError(
#     140         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     141     )
#     142 if callable(api_key):
#     143     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
print(choices, final_probs)
# Out:
# ['envelope', 'box'] [0.9253858286395246, 0.07461417136047549]
